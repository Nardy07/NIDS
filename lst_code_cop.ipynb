# %% [markdown]
# <a href="https://colab.research.google.com/github/Nardy07/NIDS/blob/main/lst_code_cop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping

# %%
df= pd.read_csv('multi_data.csv')

# %%
df
# Out:
#         Unnamed: 0  Src_Port  Dst_Port  Protocol  Bwd_Header_Len  Pkt_Len_Max  \
# 0                0 -0.759847  2.342361  0.057304        0.227105     2.263739
# 1                1  1.608301 -0.565280  0.057304        1.008856     7.119662
# 2                2  0.783030 -0.586593  0.057304       -0.014527     0.006001
# 3                3 -0.777205  1.329155  0.057304       -0.051482    -0.164223
# 4                4  1.930986 -0.565280  0.057304        0.063648     0.528413
# ...            ...       ...       ...       ...             ...          ...
# 205162      205162  1.088268 -0.346626  0.057304       -0.018791    -0.158086
# 205163      205163  1.088312 -0.346626  0.057304        0.026693    -0.153017
# 205164      205164  1.214003 -0.581893  0.057304        0.003951    -0.156219
# 205165      205165  1.088268 -0.346626  0.057304       -0.018791    -0.158086
# 205166      205166  1.088312 -0.346626  0.057304        0.026693    -0.156219
#
#         Pkt_Len_Mean  Pkt_Len_Var  Pkt_Size_Avg  Fwd_Seg_Size_Avg  \
# 0           4.590637     0.471796      4.347100          8.173076
# 1           5.353110     0.980947      5.031255         -0.125103
# 2          -0.035646    -0.047994     -0.041103         -0.115746
# 3          -0.281857    -0.053107     -0.296156         -0.154458
# 4           1.018069     0.008384      0.970252          0.021508
# ...              ...          ...           ...               ...
# 205162     -0.269257    -0.053094     -0.281918         -0.154458
# 205163     -0.244059    -0.053066     -0.257822         -0.087005
# 205164     -0.248989    -0.053076     -0.262389         -0.125131
# 205165     -0.269257    -0.053094     -0.281918         -0.154458
# 205166     -0.251102    -0.053082     -0.264965         -0.101669
#
#         Init_Bwd_Win_Byts  intrusion   DDoS  Normal    U2R  Probe    DoS  \
# 0                2.477885          3  False    True  False  False  False
# 1                2.420659          3  False    True  False  False  False
# 2                2.420659          3  False    True  False  False  False
# 3                2.420615          3  False    True  False  False  False
# 4                2.420659          3  False    True  False  False  False
# ...                   ...        ...    ...     ...    ...    ...    ...
# 205162          -0.415265          5  False   False   True  False  False
# 205163          -0.415265          5  False   False   True  False  False
# 205164          -0.408592          5  False   False   True  False  False
# 205165          -0.415265          5  False   False   True  False  False
# 205166          -0.415265          5  False   False   True  False  False
#
#           BFA   Label
# 0       False  Normal
# 1       False  Normal
# 2       False  Normal
# 3       False  Normal
# 4       False  Normal
# ...       ...     ...
# 205162  False     U2R
# 205163  False     U2R
# 205164  False     U2R
# 205165  False     U2R
# 205166  False     U2R
#
# [205167 rows x 19 columns]

# %%
df = df.drop(df.columns[0], axis=1)

# %%
df
# Out:
#         Src_Port  Dst_Port  Protocol  Bwd_Header_Len  Pkt_Len_Max  \
# 0      -0.759847  2.342361  0.057304        0.227105     2.263739
# 1       1.608301 -0.565280  0.057304        1.008856     7.119662
# 2       0.783030 -0.586593  0.057304       -0.014527     0.006001
# 3      -0.777205  1.329155  0.057304       -0.051482    -0.164223
# 4       1.930986 -0.565280  0.057304        0.063648     0.528413
# ...          ...       ...       ...             ...          ...
# 205162  1.088268 -0.346626  0.057304       -0.018791    -0.158086
# 205163  1.088312 -0.346626  0.057304        0.026693    -0.153017
# 205164  1.214003 -0.581893  0.057304        0.003951    -0.156219
# 205165  1.088268 -0.346626  0.057304       -0.018791    -0.158086
# 205166  1.088312 -0.346626  0.057304        0.026693    -0.156219
#
#         Pkt_Len_Mean  Pkt_Len_Var  Pkt_Size_Avg  Fwd_Seg_Size_Avg  \
# 0           4.590637     0.471796      4.347100          8.173076
# 1           5.353110     0.980947      5.031255         -0.125103
# 2          -0.035646    -0.047994     -0.041103         -0.115746
# 3          -0.281857    -0.053107     -0.296156         -0.154458
# 4           1.018069     0.008384      0.970252          0.021508
# ...              ...          ...           ...               ...
# 205162     -0.269257    -0.053094     -0.281918         -0.154458
# 205163     -0.244059    -0.053066     -0.257822         -0.087005
# 205164     -0.248989    -0.053076     -0.262389         -0.125131
# 205165     -0.269257    -0.053094     -0.281918         -0.154458
# 205166     -0.251102    -0.053082     -0.264965         -0.101669
#
#         Init_Bwd_Win_Byts  intrusion   DDoS  Normal    U2R  Probe    DoS  \
# 0                2.477885          3  False    True  False  False  False
# 1                2.420659          3  False    True  False  False  False
# 2                2.420659          3  False    True  False  False  False
# 3                2.420615          3  False    True  False  False  False
# 4                2.420659          3  False    True  False  False  False
# ...                   ...        ...    ...     ...    ...    ...    ...
# 205162          -0.415265          5  False   False   True  False  False
# 205163          -0.415265          5  False   False   True  False  False
# 205164          -0.408592          5  False   False   True  False  False
# 205165          -0.415265          5  False   False   True  False  False
# 205166          -0.415265          5  False   False   True  False  False
#
#           BFA   Label
# 0       False  Normal
# 1       False  Normal
# 2       False  Normal
# 3       False  Normal
# 4       False  Normal
# ...       ...     ...
# 205162  False     U2R
# 205163  False     U2R
# 205164  False     U2R
# 205165  False     U2R
# 205166  False     U2R
#
# [205167 rows x 18 columns]

# %%
X = df.iloc[:,0:10] # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = df[['intrusion']].values # target attribute

# %%
X
# Out:
#         Src_Port  Dst_Port  Protocol  Bwd_Header_Len  Pkt_Len_Max  \
# 0      -0.759847  2.342361  0.057304        0.227105     2.263739
# 1       1.608301 -0.565280  0.057304        1.008856     7.119662
# 2       0.783030 -0.586593  0.057304       -0.014527     0.006001
# 3      -0.777205  1.329155  0.057304       -0.051482    -0.164223
# 4       1.930986 -0.565280  0.057304        0.063648     0.528413
# ...          ...       ...       ...             ...          ...
# 205162  1.088268 -0.346626  0.057304       -0.018791    -0.158086
# 205163  1.088312 -0.346626  0.057304        0.026693    -0.153017
# 205164  1.214003 -0.581893  0.057304        0.003951    -0.156219
# 205165  1.088268 -0.346626  0.057304       -0.018791    -0.158086
# 205166  1.088312 -0.346626  0.057304        0.026693    -0.156219
#
#         Pkt_Len_Mean  Pkt_Len_Var  Pkt_Size_Avg  Fwd_Seg_Size_Avg  \
# 0           4.590637     0.471796      4.347100          8.173076
# 1           5.353110     0.980947      5.031255         -0.125103
# 2          -0.035646    -0.047994     -0.041103         -0.115746
# 3          -0.281857    -0.053107     -0.296156         -0.154458
# 4           1.018069     0.008384      0.970252          0.021508
# ...              ...          ...           ...               ...
# 205162     -0.269257    -0.053094     -0.281918         -0.154458
# 205163     -0.244059    -0.053066     -0.257822         -0.087005
# 205164     -0.248989    -0.053076     -0.262389         -0.125131
# 205165     -0.269257    -0.053094     -0.281918         -0.154458
# 205166     -0.251102    -0.053082     -0.264965         -0.101669
#
#         Init_Bwd_Win_Byts
# 0                2.477885
# 1                2.420659
# 2                2.420659
# 3                2.420615
# 4                2.420659
# ...                   ...
# 205162          -0.415265
# 205163          -0.415265
# 205164          -0.408592
# 205165          -0.415265
# 205166          -0.415265
#
# [205167 rows x 10 columns]

# %%
from sklearn.metrics import accuracy_score # for calculating accuracy of model
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import classification_report # for generating a classification report of model
import pickle # saving and loading trained model
from os import path

# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
X_train = X_train.values

# %%
print(X_train.shape)
# Out:
# (153875, 10)

# %%
y_train=np.array(y_train)

# %%
num_classes=6
y_train_one_hot = to_categorical(y_train, num_classes)
#y_val_one_hot = to_categorical(y_val, num_classes)
y_test_one_hot = to_categorical(y_test, num_classes)

# %%
x_train = np.reshape(X_train,(X_train.shape[0],1,X_train.shape[1]))

# %%
x_train.shape
# Out:
# (153875, 1, 10)

# %% [markdown]
# # LSTM model defining
# first ko pailako save garya model
#
# second ko chai naya layer add garera activation ma softmax used.
#
# third ko ma similar to second tara activation ma chai sigmoid nai use.

# %%
#lst = Sequential() # initializing model

# FIRST ONEEE 99% accuracy

# input layer and LSTM layer with 50 neurons
#lst.add(LSTM(units=50,input_dim=10))
 #output layer with sigmoid activation
#lst.add(Dense(1, activation='sigmoid'))

# SECOND ONE 50%

#lst.add(LSTM(units=50, return_sequences=True, input_dim=10))
#lst.add(Dropout(0.2))
#lst.add(LSTM(units=50, return_sequences=True))
#lst.add(Dropout(0.2))
#lst.add(LSTM(units=50))
#lst.add(Dropout(0.2))
#lst.add(Dense(1, activation='softmax')) <-------- esma activation function change garera accuracy ghatna sakya huna sakcha

# THIRD ONE ~99%

lst = Sequential([LSTM(128, input_dim=10, return_sequences=True),Dropout(0.2),LSTM(128,return_sequences=True),Dropout(0.2),LSTM(128),Dropout(0.2),Dense(num_classes, activation='softmax')])

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# summary of model layers
lst.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, None, 128)         71168
#
#  dropout_9 (Dropout)         (None, None, 128)         0
#
#  lstm_10 (LSTM)              (None, None, 128)         131584
#
#  dropout_10 (Dropout)        (None, None, 128)         0
#
#  lstm_11 (LSTM)              (None, 128)               131584
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_3 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 335110 (1.28 MB)
# Trainable params: 335110 (1.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# training the model on training dataset
history = lst.fit(x_train, y_train_one_hot, epochs=100, batch_size=16,validation_split=0.2)
# Out:
# Epoch 1/100
# 7694/7694 [==============================] - 86s 10ms/step - loss: 0.0651 - accuracy: 0.9855 - val_loss: 0.0449 - val_accuracy: 0.9901
# Epoch 2/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0396 - accuracy: 0.9912 - val_loss: 0.0464 - val_accuracy: 0.9890
# Epoch 3/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0340 - accuracy: 0.9921 - val_loss: 0.0285 - val_accuracy: 0.9930
# Epoch 4/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0279 - accuracy: 0.9936 - val_loss: 0.0236 - val_accuracy: 0.9939
# Epoch 5/100
# 7694/7694 [==============================] - 77s 10ms/step - loss: 0.0240 - accuracy: 0.9944 - val_loss: 0.0224 - val_accuracy: 0.9952
# Epoch 6/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0214 - accuracy: 0.9954 - val_loss: 0.0180 - val_accuracy: 0.9967
# Epoch 7/100
# 7694/7694 [==============================] - 82s 11ms/step - loss: 0.0210 - accuracy: 0.9955 - val_loss: 0.0174 - val_accuracy: 0.9970
# Epoch 8/100
# 7694/7694 [==============================] - 101s 13ms/step - loss: 0.0199 - accuracy: 0.9957 - val_loss: 0.0230 - val_accuracy: 0.9954
# Epoch 9/100
# 7694/7694 [==============================] - 106s 14ms/step - loss: 0.0187 - accuracy: 0.9962 - val_loss: 0.0179 - val_accuracy: 0.9971
# Epoch 10/100
# 7694/7694 [==============================] - 105s 14ms/step - loss: 0.0185 - accuracy: 0.9964 - val_loss: 0.0186 - val_accuracy: 0.9971
# Epoch 11/100
# 7694/7694 [==============================] - 106s 14ms/step - loss: 0.0190 - accuracy: 0.9961 - val_loss: 0.0173 - val_accuracy: 0.9971
# Epoch 12/100
# 7694/7694 [==============================] - 102s 13ms/step - loss: 0.0177 - accuracy: 0.9965 - val_loss: 0.0243 - val_accuracy: 0.9957
# Epoch 13/100
# 7694/7694 [==============================] - 107s 14ms/step - loss: 0.0182 - accuracy: 0.9965 - val_loss: 0.0170 - val_accuracy: 0.9970
# Epoch 14/100
# 7694/7694 [==============================] - 97s 13ms/step - loss: 0.0176 - accuracy: 0.9967 - val_loss: 0.0159 - val_accuracy: 0.9973
# Epoch 15/100
# 7694/7694 [==============================] - 89s 12ms/step - loss: 0.0177 - accuracy: 0.9967 - val_loss: 0.0181 - val_accuracy: 0.9964
# Epoch 16/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0171 - accuracy: 0.9966 - val_loss: 0.0166 - val_accuracy: 0.9971
# Epoch 17/100
# 7694/7694 [==============================] - 106s 14ms/step - loss: 0.0173 - accuracy: 0.9968 - val_loss: 0.0167 - val_accuracy: 0.9971
# Epoch 18/100
# 7694/7694 [==============================] - 105s 14ms/step - loss: 0.0172 - accuracy: 0.9967 - val_loss: 0.0200 - val_accuracy: 0.9962
# Epoch 19/100
# 7694/7694 [==============================] - 101s 13ms/step - loss: 0.0164 - accuracy: 0.9971 - val_loss: 0.0196 - val_accuracy: 0.9965
# Epoch 20/100
# 7694/7694 [==============================] - 98s 13ms/step - loss: 0.0170 - accuracy: 0.9969 - val_loss: 0.0174 - val_accuracy: 0.9971
# Epoch 21/100
# 7694/7694 [==============================] - 77s 10ms/step - loss: 0.0165 - accuracy: 0.9970 - val_loss: 0.0189 - val_accuracy: 0.9970
# Epoch 22/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0166 - accuracy: 0.9969 - val_loss: 0.0196 - val_accuracy: 0.9965
# Epoch 23/100
# 7694/7694 [==============================] - 77s 10ms/step - loss: 0.0166 - accuracy: 0.9969 - val_loss: 0.0188 - val_accuracy: 0.9964
# Epoch 24/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0166 - accuracy: 0.9970 - val_loss: 0.0180 - val_accuracy: 0.9964
# Epoch 25/100
# 7694/7694 [==============================] - 77s 10ms/step - loss: 0.0169 - accuracy: 0.9970 - val_loss: 0.0163 - val_accuracy: 0.9974
# Epoch 26/100
# 7694/7694 [==============================] - 84s 11ms/step - loss: 0.0167 - accuracy: 0.9971 - val_loss: 0.0191 - val_accuracy: 0.9961
# Epoch 27/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0161 - accuracy: 0.9971 - val_loss: 0.0162 - val_accuracy: 0.9971
# Epoch 28/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0163 - accuracy: 0.9971 - val_loss: 0.0169 - val_accuracy: 0.9971
# Epoch 29/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0164 - accuracy: 0.9969 - val_loss: 0.0161 - val_accuracy: 0.9974
# Epoch 30/100
# 7694/7694 [==============================] - 83s 11ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 0.0162 - val_accuracy: 0.9974
# Epoch 31/100
# 7694/7694 [==============================] - 77s 10ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 0.0198 - val_accuracy: 0.9965
# Epoch 32/100
# 7694/7694 [==============================] - 85s 11ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 0.0162 - val_accuracy: 0.9973
# Epoch 33/100
# 7694/7694 [==============================] - 88s 11ms/step - loss: 0.0158 - accuracy: 0.9972 - val_loss: 0.0162 - val_accuracy: 0.9975
# Epoch 34/100
# 7694/7694 [==============================] - 85s 11ms/step - loss: 0.0166 - accuracy: 0.9970 - val_loss: 0.0166 - val_accuracy: 0.9971
# Epoch 35/100
# 7694/7694 [==============================] - 81s 10ms/step - loss: 0.0162 - accuracy: 0.9972 - val_loss: 0.0168 - val_accuracy: 0.9973
# Epoch 36/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0157 - accuracy: 0.9973 - val_loss: 0.0164 - val_accuracy: 0.9972
# Epoch 37/100
# 7694/7694 [==============================] - 79s 10ms/step - loss: 0.0162 - accuracy: 0.9972 - val_loss: 0.0159 - val_accuracy: 0.9974
# Epoch 38/100
# 7694/7694 [==============================] - 97s 13ms/step - loss: 0.0159 - accuracy: 0.9973 - val_loss: 0.0205 - val_accuracy: 0.9955
# Epoch 39/100
# 7694/7694 [==============================] - 102s 13ms/step - loss: 0.0161 - accuracy: 0.9972 - val_loss: 0.0160 - val_accuracy: 0.9973
# Epoch 40/100
# 7694/7694 [==============================] - 103s 13ms/step - loss: 0.0158 - accuracy: 0.9972 - val_loss: 0.0171 - val_accuracy: 0.9973
# Epoch 41/100
# 7694/7694 [==============================] - 88s 11ms/step - loss: 0.0159 - accuracy: 0.9972 - val_loss: 0.0162 - val_accuracy: 0.9973
# Epoch 42/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0152 - accuracy: 0.9974 - val_loss: 0.0162 - val_accuracy: 0.9974
# Epoch 43/100
# 7694/7694 [==============================] - 79s 10ms/step - loss: 0.0159 - accuracy: 0.9972 - val_loss: 0.0163 - val_accuracy: 0.9974
# Epoch 44/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0160 - accuracy: 0.9972 - val_loss: 0.0174 - val_accuracy: 0.9969
# Epoch 45/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0158 - accuracy: 0.9972 - val_loss: 0.0185 - val_accuracy: 0.9966
# Epoch 46/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0157 - accuracy: 0.9973 - val_loss: 0.0163 - val_accuracy: 0.9974
# Epoch 47/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0159 - accuracy: 0.9973 - val_loss: 0.0181 - val_accuracy: 0.9970
# Epoch 48/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0156 - accuracy: 0.9973 - val_loss: 0.0164 - val_accuracy: 0.9974
# Epoch 49/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0157 - accuracy: 0.9973 - val_loss: 0.0181 - val_accuracy: 0.9968
# Epoch 50/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0159 - val_accuracy: 0.9974
# Epoch 51/100
# 7694/7694 [==============================] - 79s 10ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0180 - val_accuracy: 0.9967
# Epoch 52/100
# 7694/7694 [==============================] - 81s 10ms/step - loss: 0.0157 - accuracy: 0.9973 - val_loss: 0.0163 - val_accuracy: 0.9973
# Epoch 53/100
# 7694/7694 [==============================] - 84s 11ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0167 - val_accuracy: 0.9972
# Epoch 54/100
# 7694/7694 [==============================] - 77s 10ms/step - loss: 0.0154 - accuracy: 0.9973 - val_loss: 0.0166 - val_accuracy: 0.9972
# Epoch 55/100
# 7694/7694 [==============================] - 85s 11ms/step - loss: 0.0153 - accuracy: 0.9973 - val_loss: 0.0164 - val_accuracy: 0.9974
# Epoch 56/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0158 - accuracy: 0.9972 - val_loss: 0.0168 - val_accuracy: 0.9968
# Epoch 57/100
# 7694/7694 [==============================] - 77s 10ms/step - loss: 0.0152 - accuracy: 0.9974 - val_loss: 0.0203 - val_accuracy: 0.9965
# Epoch 58/100
# 7694/7694 [==============================] - 77s 10ms/step - loss: 0.0158 - accuracy: 0.9973 - val_loss: 0.0170 - val_accuracy: 0.9969
# Epoch 59/100
# 7694/7694 [==============================] - 78s 10ms/step - loss: 0.0154 - accuracy: 0.9973 - val_loss: 0.0185 - val_accuracy: 0.9965
# Epoch 60/100
# 7694/7694 [==============================] - 105s 14ms/step - loss: 0.0153 - accuracy: 0.9973 - val_loss: 0.0171 - val_accuracy: 0.9973
# Epoch 61/100
# 7694/7694 [==============================] - 100s 13ms/step - loss: 0.0157 - accuracy: 0.9974 - val_loss: 0.0184 - val_accuracy: 0.9968
# Epoch 62/100
# 7694/7694 [==============================] - 102s 13ms/step - loss: 0.0155 - accuracy: 0.9973 - val_loss: 0.0170 - val_accuracy: 0.9974
# Epoch 63/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0154 - accuracy: 0.9973 - val_loss: 0.0170 - val_accuracy: 0.9972
# Epoch 64/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0156 - accuracy: 0.9973 - val_loss: 0.0167 - val_accuracy: 0.9973
# Epoch 65/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0163 - val_accuracy: 0.9974
# Epoch 66/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0169 - val_accuracy: 0.9972
# Epoch 67/100
# 7694/7694 [==============================] - 79s 10ms/step - loss: 0.0153 - accuracy: 0.9973 - val_loss: 0.0169 - val_accuracy: 0.9973
# Epoch 68/100
# 7694/7694 [==============================] - 84s 11ms/step - loss: 0.0156 - accuracy: 0.9973 - val_loss: 0.0160 - val_accuracy: 0.9974
# Epoch 69/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0156 - accuracy: 0.9974 - val_loss: 0.0167 - val_accuracy: 0.9971
# Epoch 70/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0149 - accuracy: 0.9974 - val_loss: 0.0166 - val_accuracy: 0.9974
# Epoch 71/100
# 7694/7694 [==============================] - 84s 11ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0172 - val_accuracy: 0.9973
# Epoch 72/100
# 7694/7694 [==============================] - 87s 11ms/step - loss: 0.0155 - accuracy: 0.9973 - val_loss: 0.0163 - val_accuracy: 0.9974
# Epoch 73/100
# 7694/7694 [==============================] - 82s 11ms/step - loss: 0.0150 - accuracy: 0.9975 - val_loss: 0.0169 - val_accuracy: 0.9971
# Epoch 74/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0152 - accuracy: 0.9974 - val_loss: 0.0162 - val_accuracy: 0.9975
# Epoch 75/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0153 - accuracy: 0.9973 - val_loss: 0.0163 - val_accuracy: 0.9974
# Epoch 76/100
# 7694/7694 [==============================] - 82s 11ms/step - loss: 0.0150 - accuracy: 0.9974 - val_loss: 0.0168 - val_accuracy: 0.9974
# Epoch 77/100
# 7694/7694 [==============================] - 82s 11ms/step - loss: 0.0150 - accuracy: 0.9974 - val_loss: 0.0175 - val_accuracy: 0.9972
# Epoch 78/100
# 7694/7694 [==============================] - 87s 11ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0174 - val_accuracy: 0.9973
# Epoch 79/100
# 7694/7694 [==============================] - 81s 10ms/step - loss: 0.0150 - accuracy: 0.9974 - val_loss: 0.0164 - val_accuracy: 0.9974
# Epoch 80/100
# 7694/7694 [==============================] - 81s 10ms/step - loss: 0.0150 - accuracy: 0.9974 - val_loss: 0.0175 - val_accuracy: 0.9973
# Epoch 81/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0150 - accuracy: 0.9974 - val_loss: 0.0173 - val_accuracy: 0.9970
# Epoch 82/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 0.0169 - val_accuracy: 0.9974
# Epoch 83/100
# 7694/7694 [==============================] - 86s 11ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0167 - val_accuracy: 0.9974
# Epoch 84/100
# 7694/7694 [==============================] - 89s 12ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0158 - val_accuracy: 0.9974
# Epoch 85/100
# 7694/7694 [==============================] - 82s 11ms/step - loss: 0.0150 - accuracy: 0.9975 - val_loss: 0.0168 - val_accuracy: 0.9971
# Epoch 86/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0152 - accuracy: 0.9973 - val_loss: 0.0167 - val_accuracy: 0.9974
# Epoch 87/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0145 - accuracy: 0.9975 - val_loss: 0.0169 - val_accuracy: 0.9974
# Epoch 88/100
# 7694/7694 [==============================] - 82s 11ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0174 - val_accuracy: 0.9967
# Epoch 89/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0152 - accuracy: 0.9974 - val_loss: 0.0158 - val_accuracy: 0.9974
# Epoch 90/100
# 7694/7694 [==============================] - 79s 10ms/step - loss: 0.0149 - accuracy: 0.9974 - val_loss: 0.0173 - val_accuracy: 0.9972
# Epoch 91/100
# 7694/7694 [==============================] - 82s 11ms/step - loss: 0.0152 - accuracy: 0.9974 - val_loss: 0.0173 - val_accuracy: 0.9973
# Epoch 92/100
# 7694/7694 [==============================] - 82s 11ms/step - loss: 0.0148 - accuracy: 0.9974 - val_loss: 0.0204 - val_accuracy: 0.9962
# Epoch 93/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 0.0173 - val_accuracy: 0.9973
# Epoch 94/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0148 - accuracy: 0.9975 - val_loss: 0.0177 - val_accuracy: 0.9973
# Epoch 95/100
# 7694/7694 [==============================] - 83s 11ms/step - loss: 0.0147 - accuracy: 0.9974 - val_loss: 0.0175 - val_accuracy: 0.9972
# Epoch 96/100
# 7694/7694 [==============================] - 79s 10ms/step - loss: 0.0150 - accuracy: 0.9974 - val_loss: 0.0161 - val_accuracy: 0.9974
# Epoch 97/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0151 - accuracy: 0.9975 - val_loss: 0.0175 - val_accuracy: 0.9974
# Epoch 98/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0149 - accuracy: 0.9975 - val_loss: 0.0166 - val_accuracy: 0.9974
# Epoch 99/100
# 7694/7694 [==============================] - 81s 11ms/step - loss: 0.0150 - accuracy: 0.9975 - val_loss: 0.0171 - val_accuracy: 0.9974
# Epoch 100/100
# 7694/7694 [==============================] - 80s 10ms/step - loss: 0.0148 - accuracy: 0.9974 - val_loss: 0.0162 - val_accuracy: 0.9974

# %%
X_test = X_test.to_numpy()
x_test = np.reshape(X_test, (X_test.shape[0],1,X_test.shape[1]))

# %%
from keras.models import model_from_json # saving and loading trained model

filepath = 'lst_multi.json'
weightspath = 'lst_multi.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  lst_json = lst.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(lst_json)

  # serialize weights to HDF5
  lst.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  lst = model_from_json(loaded_model_json)

  # load weights into new model
  lst.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# load json and create model
json_file = open(filepath, 'r')
loaded_model_json = json_file.read()
json_file.close()
lst = model_from_json(loaded_model_json)

# load weights into new model
lst.load_weights(weightspath)
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = lst.evaluate(x_test, y_test_one_hot, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 1603/1603 [==============================] - 8s 5ms/step - loss: 0.0148 - accuracy: 0.9976
# Test results - Loss: 0.014778001233935356 - Accuracy: 99.76409673690796%

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('lstm_multi_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('lstm_multi_loss.png')
plt.show()

# %%
from keras.utils import plot_model
# representation of model layers
plot_model(lst, to_file='lstm_multi.png', show_shapes=True,)

# %%
y_test_one_hot.shape
# Out:
# (51292, 6)

# %%
y_pred = lst.predict(x_test)
# Out:
# 1603/1603 [==============================] - 9s 5ms/step

# %%
y_pred.shape
# Out:
# (51292, 6)

# %%
y_classes = (lst.predict(x_test)>0.5).astype('int32')
# Out:
# 1603/1603 [==============================] - 14s 9ms/step

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
print("Recall Score - ",recall_score(y_test_one_hot,y_classes,average='micro'))
print("F1 Score - ",f1_score(y_test_one_hot,y_classes,average='micro'))
print("Precision Score - ",precision_score(y_test_one_hot,y_classes,average='micro'))
# Out:
# Recall Score -  0.9976409576542151
# F1 Score -  0.9976604082587589
# Precision Score -  0.9976798596217586

# %%
print("y_true shape:", y_true.shape)
print("y_classes shape:", predicted_classes.shape)
# Out:
# y_true shape: (51292,)
# y_classes shape: (51292,)

# %%
print("y_true type:", type(y_true))
print("y_classes type:", type(y_classes))
# Out:
# y_true type: <class 'numpy.ndarray'>
# y_classes type: <class 'numpy.ndarray'>

# %%
y_true = np.argmax(y_test, axis=1)
predicted_classes = np.argmax(y_pred, axis=1)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,precision_recall_fscore_support
from sklearn.metrics import f1_score,roc_auc_score
import seaborn as sns
#precision,recall,fscore,none = precision_recall_fscore_support(y_pred,y_test_one_hot,average='weighted')
cm=confusion_matrix(y_true,predicted_classes)
f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel('Predicted')
plt.ylabel("Actual")
plt.show()

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, predicted_classes)

# Plot confusion matrix
#plt.figure(figsize=(10, 8))
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class {}'.format(i) for i in range(conf_matrix.shape[0])], yticklabels=['Class {}'.format(i) for i in range(conf_matrix.shape[0])])
#plt.title('Confusion Matrix')
#plt.xlabel('Predicted')
#plt.ylabel('Actual')
#plt.tight_layout()
#plt.savefig('confusion_matrix.png')
#plt.show()
