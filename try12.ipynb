# %% [markdown]
# <a href="https://colab.research.google.com/github/Nardy07/NIDS/blob/main/try12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping

# %%
df= pd.read_csv('balanced_data_try.csv')

# %%
df = df.drop(df.columns[0], axis=1)

# %%
df
# Out:
#         Fwd_Pkt_Len_Mean  Bwd_IAT_Tot  Bwd_IAT_Max  Pkt_Len_Max  Pkt_Len_Mean  \
# 0               0.862912     1.164843     0.149819     1.483322      2.858391
# 1              -0.154458    -0.380121    -0.374572    -0.164223     -0.281857
# 2               0.138330    -0.378386    -0.372989    -0.026283     -0.077528
# 3              -0.154458    -0.380180    -0.374651    -0.164223     -0.281857
# 4              -0.154458    -0.380180    -0.374651    -0.164223     -0.281857
# ...                  ...          ...          ...          ...           ...
# 136843         -0.125131     2.022758     2.871826    -0.156219     -0.263929
# 136844         -0.125131     2.018876     2.866581    -0.156219     -0.263929
# 136845         -0.125131     2.030522     2.877070    -0.156219     -0.263929
# 136846         -0.154458    -0.380180    -0.374651    -0.164223     -0.281857
# 136847         -0.154458    -0.380180    -0.374651    -0.164223     -0.281857
#
#         Pkt_Len_Std  Pkt_Len_Var  Pkt_Size_Avg  Fwd_Seg_Size_Avg  \
# 0          2.085865     0.217784      2.697656          0.862912
# 1         -0.233345    -0.053107     -0.296156         -0.154458
# 2          0.016422    -0.049965     -0.086238          0.138330
# 3         -0.233345    -0.053107     -0.296156         -0.154458
# 4         -0.233345    -0.053107     -0.296156         -0.154458
# ...             ...          ...           ...               ...
# 136843    -0.213080    -0.053086     -0.277584         -0.125131
# 136844    -0.213080    -0.053086     -0.277584         -0.125131
# 136845    -0.213080    -0.053086     -0.277584         -0.125131
# 136846    -0.233345    -0.053107     -0.296156         -0.154458
# 136847    -0.233345    -0.053107     -0.296156         -0.154458
#
#         Init_Bwd_Win_Byts  intrusion  abnormal  Normal     Label
# 0                2.420659          0     False    True    Normal
# 1                2.420615          0     False    True    Normal
# 2                2.420659          0     False    True    Normal
# 3               -0.418093          1      True   False  abnormal
# 4               -0.418137          1      True   False  abnormal
# ...                   ...        ...       ...     ...       ...
# 136843          -0.415309          1      True   False  abnormal
# 136844          -0.415309          1      True   False  abnormal
# 136845          -0.415309          1      True   False  abnormal
# 136846          -0.418093          1      True   False  abnormal
# 136847          -0.418137          1      True   False  abnormal
#
# [136848 rows x 14 columns]

# %%
X = df.iloc[:,0:10] # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = df[['intrusion']].values # target attribute

# %%
X
# Out:
#         Fwd_Pkt_Len_Mean  Bwd_IAT_Tot  Bwd_IAT_Max  Pkt_Len_Max  Pkt_Len_Mean  \
# 0               0.862912     1.164843     0.149819     1.483322      2.858391
# 1              -0.154458    -0.380121    -0.374572    -0.164223     -0.281857
# 2               0.138330    -0.378386    -0.372989    -0.026283     -0.077528
# 3              -0.154458    -0.380180    -0.374651    -0.164223     -0.281857
# 4              -0.154458    -0.380180    -0.374651    -0.164223     -0.281857
# ...                  ...          ...          ...          ...           ...
# 136843         -0.125131     2.022758     2.871826    -0.156219     -0.263929
# 136844         -0.125131     2.018876     2.866581    -0.156219     -0.263929
# 136845         -0.125131     2.030522     2.877070    -0.156219     -0.263929
# 136846         -0.154458    -0.380180    -0.374651    -0.164223     -0.281857
# 136847         -0.154458    -0.380180    -0.374651    -0.164223     -0.281857
#
#         Pkt_Len_Std  Pkt_Len_Var  Pkt_Size_Avg  Fwd_Seg_Size_Avg  \
# 0          2.085865     0.217784      2.697656          0.862912
# 1         -0.233345    -0.053107     -0.296156         -0.154458
# 2          0.016422    -0.049965     -0.086238          0.138330
# 3         -0.233345    -0.053107     -0.296156         -0.154458
# 4         -0.233345    -0.053107     -0.296156         -0.154458
# ...             ...          ...           ...               ...
# 136843    -0.213080    -0.053086     -0.277584         -0.125131
# 136844    -0.213080    -0.053086     -0.277584         -0.125131
# 136845    -0.213080    -0.053086     -0.277584         -0.125131
# 136846    -0.233345    -0.053107     -0.296156         -0.154458
# 136847    -0.233345    -0.053107     -0.296156         -0.154458
#
#         Init_Bwd_Win_Byts
# 0                2.420659
# 1                2.420615
# 2                2.420659
# 3               -0.418093
# 4               -0.418137
# ...                   ...
# 136843          -0.415309
# 136844          -0.415309
# 136845          -0.415309
# 136846          -0.418093
# 136847          -0.418137
#
# [136848 rows x 10 columns]

# %%
from sklearn.metrics import accuracy_score # for calculating accuracy of model
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import classification_report # for generating a classification report of model
import pickle # saving and loading trained model
from os import path

# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
X_train = X_train.values

# %%
y_train=np.array(y_train)

# %%
x_train = np.reshape(X_train,(X_train.shape[0],1,X_train.shape[1]))

# %%
x_train.shape
# Out:
# (102636, 1, 10)

# %% [markdown]
# # LSTM model defining
# first ko pailako save garya model
#
# second ko chai naya layer add garera activation ma softmax used.
#
# third ko ma similar to second tara activation ma chai sigmoid nai use.

# %%
#lst = Sequential() # initializing model

# FIRST ONEEE 99% accuracy

# input layer and LSTM layer with 50 neurons
#lst.add(LSTM(units=50,input_dim=10))
 #output layer with sigmoid activation
#lst.add(Dense(1, activation='sigmoid'))

# SECOND ONE 50%

#lst.add(LSTM(units=50, return_sequences=True, input_dim=10))
#lst.add(Dropout(0.2))
#lst.add(LSTM(units=50, return_sequences=True))
#lst.add(Dropout(0.2))
#lst.add(LSTM(units=50))
#lst.add(Dropout(0.2))
#lst.add(Dense(1, activation='softmax')) <-------- esma activation function change garera accuracy ghatna sakya huna sakcha

# THIRD ONE ~99%

lst = Sequential([LSTM(64, input_dim=10, return_sequences=True),Dropout(0.2),LSTM(32),Dropout(0.2),Dense(1, activation='sigmoid')])

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# summary of model layers
lst.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, None, 64)          19200
#
#  dropout_2 (Dropout)         (None, None, 64)          0
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 31649 (123.63 KB)
# Trainable params: 31649 (123.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# training the model on training dataset
history = lst.fit(x_train, y_train, epochs=150, batch_size=16,validation_split=0.2)
# Out:
# Epoch 1/150
# 5132/5132 [==============================] - 17s 3ms/step - loss: 0.0593 - accuracy: 0.9856 - val_loss: 0.0359 - val_accuracy: 0.9913
# Epoch 2/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0404 - accuracy: 0.9904 - val_loss: 0.0370 - val_accuracy: 0.9915
# Epoch 3/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0397 - accuracy: 0.9904 - val_loss: 0.0359 - val_accuracy: 0.9916
# Epoch 4/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0391 - accuracy: 0.9909 - val_loss: 0.0357 - val_accuracy: 0.9918
# Epoch 5/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0388 - accuracy: 0.9909 - val_loss: 0.0344 - val_accuracy: 0.9916
# Epoch 6/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0382 - accuracy: 0.9910 - val_loss: 0.0345 - val_accuracy: 0.9918
# Epoch 7/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0382 - accuracy: 0.9911 - val_loss: 0.0353 - val_accuracy: 0.9919
# Epoch 8/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0381 - accuracy: 0.9912 - val_loss: 0.0338 - val_accuracy: 0.9925
# Epoch 9/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0379 - accuracy: 0.9913 - val_loss: 0.0351 - val_accuracy: 0.9925
# Epoch 10/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0376 - accuracy: 0.9914 - val_loss: 0.0339 - val_accuracy: 0.9919
# Epoch 11/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0374 - accuracy: 0.9915 - val_loss: 0.0337 - val_accuracy: 0.9920
# Epoch 12/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0372 - accuracy: 0.9917 - val_loss: 0.0334 - val_accuracy: 0.9920
# Epoch 13/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0369 - accuracy: 0.9915 - val_loss: 0.0336 - val_accuracy: 0.9920
# Epoch 14/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0370 - accuracy: 0.9916 - val_loss: 0.0328 - val_accuracy: 0.9927
# Epoch 15/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0366 - accuracy: 0.9918 - val_loss: 0.0347 - val_accuracy: 0.9920
# Epoch 16/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0367 - accuracy: 0.9918 - val_loss: 0.0330 - val_accuracy: 0.9928
# Epoch 17/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0365 - accuracy: 0.9918 - val_loss: 0.0335 - val_accuracy: 0.9920
# Epoch 18/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0364 - accuracy: 0.9920 - val_loss: 0.0322 - val_accuracy: 0.9928
# Epoch 19/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0363 - accuracy: 0.9918 - val_loss: 0.0323 - val_accuracy: 0.9928
# Epoch 20/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0360 - accuracy: 0.9919 - val_loss: 0.0330 - val_accuracy: 0.9928
# Epoch 21/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0363 - accuracy: 0.9918 - val_loss: 0.0338 - val_accuracy: 0.9930
# Epoch 22/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0360 - accuracy: 0.9920 - val_loss: 0.0320 - val_accuracy: 0.9928
# Epoch 23/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0359 - accuracy: 0.9919 - val_loss: 0.0320 - val_accuracy: 0.9928
# Epoch 24/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0355 - accuracy: 0.9921 - val_loss: 0.0334 - val_accuracy: 0.9921
# Epoch 25/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0362 - accuracy: 0.9919 - val_loss: 0.0319 - val_accuracy: 0.9928
# Epoch 26/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0355 - accuracy: 0.9921 - val_loss: 0.0316 - val_accuracy: 0.9928
# Epoch 27/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0357 - accuracy: 0.9920 - val_loss: 0.0320 - val_accuracy: 0.9928
# Epoch 28/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0358 - accuracy: 0.9920 - val_loss: 0.0341 - val_accuracy: 0.9921
# Epoch 29/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0353 - accuracy: 0.9920 - val_loss: 0.0321 - val_accuracy: 0.9928
# Epoch 30/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0355 - accuracy: 0.9921 - val_loss: 0.0317 - val_accuracy: 0.9928
# Epoch 31/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0351 - accuracy: 0.9921 - val_loss: 0.0312 - val_accuracy: 0.9928
# Epoch 32/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0354 - accuracy: 0.9920 - val_loss: 0.0331 - val_accuracy: 0.9927
# Epoch 33/150
# 5132/5132 [==============================] - 15s 3ms/step - loss: 0.0351 - accuracy: 0.9921 - val_loss: 0.0325 - val_accuracy: 0.9928
# Epoch 34/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0352 - accuracy: 0.9921 - val_loss: 0.0317 - val_accuracy: 0.9928
# Epoch 35/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0351 - accuracy: 0.9922 - val_loss: 0.0320 - val_accuracy: 0.9929
# Epoch 36/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0349 - accuracy: 0.9921 - val_loss: 0.0335 - val_accuracy: 0.9928
# Epoch 37/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0348 - accuracy: 0.9922 - val_loss: 0.0313 - val_accuracy: 0.9928
# Epoch 38/150
# 5132/5132 [==============================] - 15s 3ms/step - loss: 0.0348 - accuracy: 0.9921 - val_loss: 0.0311 - val_accuracy: 0.9928
# Epoch 39/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0348 - accuracy: 0.9922 - val_loss: 0.0314 - val_accuracy: 0.9929
# Epoch 40/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0349 - accuracy: 0.9921 - val_loss: 0.0308 - val_accuracy: 0.9928
# Epoch 41/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0350 - accuracy: 0.9923 - val_loss: 0.0311 - val_accuracy: 0.9929
# Epoch 42/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0347 - accuracy: 0.9923 - val_loss: 0.0308 - val_accuracy: 0.9929
# Epoch 43/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0347 - accuracy: 0.9921 - val_loss: 0.0313 - val_accuracy: 0.9929
# Epoch 44/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0345 - accuracy: 0.9923 - val_loss: 0.0338 - val_accuracy: 0.9935
# Epoch 45/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0346 - accuracy: 0.9922 - val_loss: 0.0327 - val_accuracy: 0.9929
# Epoch 46/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0345 - accuracy: 0.9923 - val_loss: 0.0304 - val_accuracy: 0.9929
# Epoch 47/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0346 - accuracy: 0.9922 - val_loss: 0.0313 - val_accuracy: 0.9929
# Epoch 48/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0345 - accuracy: 0.9922 - val_loss: 0.0305 - val_accuracy: 0.9929
# Epoch 49/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0344 - accuracy: 0.9922 - val_loss: 0.0310 - val_accuracy: 0.9929
# Epoch 50/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0340 - accuracy: 0.9922 - val_loss: 0.0314 - val_accuracy: 0.9929
# Epoch 51/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0342 - accuracy: 0.9922 - val_loss: 0.0314 - val_accuracy: 0.9929
# Epoch 52/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0338 - accuracy: 0.9924 - val_loss: 0.0313 - val_accuracy: 0.9929
# Epoch 53/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0340 - accuracy: 0.9923 - val_loss: 0.0301 - val_accuracy: 0.9931
# Epoch 54/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0341 - accuracy: 0.9924 - val_loss: 0.0300 - val_accuracy: 0.9931
# Epoch 55/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0339 - accuracy: 0.9923 - val_loss: 0.0306 - val_accuracy: 0.9929
# Epoch 56/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0338 - accuracy: 0.9923 - val_loss: 0.0301 - val_accuracy: 0.9929
# Epoch 57/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0338 - accuracy: 0.9924 - val_loss: 0.0301 - val_accuracy: 0.9935
# Epoch 58/150
# 5132/5132 [==============================] - 15s 3ms/step - loss: 0.0337 - accuracy: 0.9923 - val_loss: 0.0309 - val_accuracy: 0.9929
# Epoch 59/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0337 - accuracy: 0.9924 - val_loss: 0.0297 - val_accuracy: 0.9929
# Epoch 60/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0335 - accuracy: 0.9924 - val_loss: 0.0322 - val_accuracy: 0.9930
# Epoch 61/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0335 - accuracy: 0.9924 - val_loss: 0.0296 - val_accuracy: 0.9929
# Epoch 62/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0339 - accuracy: 0.9924 - val_loss: 0.0311 - val_accuracy: 0.9930
# Epoch 63/150
# 5132/5132 [==============================] - 15s 3ms/step - loss: 0.0334 - accuracy: 0.9922 - val_loss: 0.0298 - val_accuracy: 0.9929
# Epoch 64/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0333 - accuracy: 0.9924 - val_loss: 0.0293 - val_accuracy: 0.9931
# Epoch 65/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0334 - accuracy: 0.9925 - val_loss: 0.0326 - val_accuracy: 0.9934
# Epoch 66/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0333 - accuracy: 0.9924 - val_loss: 0.0293 - val_accuracy: 0.9935
# Epoch 67/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0334 - accuracy: 0.9924 - val_loss: 0.0314 - val_accuracy: 0.9930
# Epoch 68/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0335 - accuracy: 0.9925 - val_loss: 0.0297 - val_accuracy: 0.9936
# Epoch 69/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0332 - accuracy: 0.9924 - val_loss: 0.0290 - val_accuracy: 0.9935
# Epoch 70/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0332 - accuracy: 0.9923 - val_loss: 0.0290 - val_accuracy: 0.9936
# Epoch 71/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0332 - accuracy: 0.9923 - val_loss: 0.0286 - val_accuracy: 0.9935
# Epoch 72/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0330 - accuracy: 0.9924 - val_loss: 0.0289 - val_accuracy: 0.9931
# Epoch 73/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0326 - accuracy: 0.9925 - val_loss: 0.0287 - val_accuracy: 0.9932
# Epoch 74/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0329 - accuracy: 0.9925 - val_loss: 0.0309 - val_accuracy: 0.9936
# Epoch 75/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0330 - accuracy: 0.9924 - val_loss: 0.0294 - val_accuracy: 0.9930
# Epoch 76/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0326 - accuracy: 0.9923 - val_loss: 0.0286 - val_accuracy: 0.9936
# Epoch 77/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0328 - accuracy: 0.9923 - val_loss: 0.0293 - val_accuracy: 0.9930
# Epoch 78/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0326 - accuracy: 0.9923 - val_loss: 0.0323 - val_accuracy: 0.9930
# Epoch 79/150
# 5132/5132 [==============================] - 15s 3ms/step - loss: 0.0324 - accuracy: 0.9925 - val_loss: 0.0286 - val_accuracy: 0.9936
# Epoch 80/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0324 - accuracy: 0.9925 - val_loss: 0.0280 - val_accuracy: 0.9936
# Epoch 81/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0324 - accuracy: 0.9926 - val_loss: 0.0298 - val_accuracy: 0.9934
# Epoch 82/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0323 - accuracy: 0.9925 - val_loss: 0.0283 - val_accuracy: 0.9932
# Epoch 83/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0320 - accuracy: 0.9925 - val_loss: 0.0279 - val_accuracy: 0.9936
# Epoch 84/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0321 - accuracy: 0.9923 - val_loss: 0.0284 - val_accuracy: 0.9936
# Epoch 85/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0321 - accuracy: 0.9924 - val_loss: 0.0288 - val_accuracy: 0.9930
# Epoch 86/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0319 - accuracy: 0.9925 - val_loss: 0.0272 - val_accuracy: 0.9937
# Epoch 87/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0315 - accuracy: 0.9927 - val_loss: 0.0293 - val_accuracy: 0.9930
# Epoch 88/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0317 - accuracy: 0.9925 - val_loss: 0.0279 - val_accuracy: 0.9935
# Epoch 89/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0315 - accuracy: 0.9926 - val_loss: 0.0271 - val_accuracy: 0.9937
# Epoch 90/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0316 - accuracy: 0.9927 - val_loss: 0.0277 - val_accuracy: 0.9936
# Epoch 91/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0313 - accuracy: 0.9926 - val_loss: 0.0274 - val_accuracy: 0.9937
# Epoch 92/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0313 - accuracy: 0.9925 - val_loss: 0.0268 - val_accuracy: 0.9938
# Epoch 93/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0319 - accuracy: 0.9926 - val_loss: 0.0275 - val_accuracy: 0.9937
# Epoch 94/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0314 - accuracy: 0.9926 - val_loss: 0.0268 - val_accuracy: 0.9937
# Epoch 95/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0312 - accuracy: 0.9925 - val_loss: 0.0271 - val_accuracy: 0.9936
# Epoch 96/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0311 - accuracy: 0.9927 - val_loss: 0.0266 - val_accuracy: 0.9937
# Epoch 97/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0309 - accuracy: 0.9926 - val_loss: 0.0267 - val_accuracy: 0.9937
# Epoch 98/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0311 - accuracy: 0.9926 - val_loss: 0.0309 - val_accuracy: 0.9930
# Epoch 99/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0308 - accuracy: 0.9926 - val_loss: 0.0259 - val_accuracy: 0.9938
# Epoch 100/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0308 - accuracy: 0.9924 - val_loss: 0.0323 - val_accuracy: 0.9943
# Epoch 101/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0308 - accuracy: 0.9927 - val_loss: 0.0284 - val_accuracy: 0.9930
# Epoch 102/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0307 - accuracy: 0.9927 - val_loss: 0.0260 - val_accuracy: 0.9937
# Epoch 103/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0309 - accuracy: 0.9928 - val_loss: 0.0259 - val_accuracy: 0.9938
# Epoch 104/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0305 - accuracy: 0.9927 - val_loss: 0.0279 - val_accuracy: 0.9937
# Epoch 105/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0305 - accuracy: 0.9927 - val_loss: 0.0254 - val_accuracy: 0.9938
# Epoch 106/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0303 - accuracy: 0.9926 - val_loss: 0.0265 - val_accuracy: 0.9937
# Epoch 107/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0303 - accuracy: 0.9927 - val_loss: 0.0289 - val_accuracy: 0.9952
# Epoch 108/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0304 - accuracy: 0.9926 - val_loss: 0.0256 - val_accuracy: 0.9938
# Epoch 109/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0306 - accuracy: 0.9928 - val_loss: 0.0277 - val_accuracy: 0.9956
# Epoch 110/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0304 - accuracy: 0.9927 - val_loss: 0.0258 - val_accuracy: 0.9938
# Epoch 111/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0304 - accuracy: 0.9928 - val_loss: 0.0258 - val_accuracy: 0.9938
# Epoch 112/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0305 - accuracy: 0.9927 - val_loss: 0.0281 - val_accuracy: 0.9935
# Epoch 113/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0300 - accuracy: 0.9929 - val_loss: 0.0267 - val_accuracy: 0.9937
# Epoch 114/150
# 5132/5132 [==============================] - 15s 3ms/step - loss: 0.0299 - accuracy: 0.9929 - val_loss: 0.0249 - val_accuracy: 0.9943
# Epoch 115/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0299 - accuracy: 0.9928 - val_loss: 0.0253 - val_accuracy: 0.9943
# Epoch 116/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0301 - accuracy: 0.9927 - val_loss: 0.0248 - val_accuracy: 0.9938
# Epoch 117/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0299 - accuracy: 0.9928 - val_loss: 0.0250 - val_accuracy: 0.9938
# Epoch 118/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0299 - accuracy: 0.9927 - val_loss: 0.0260 - val_accuracy: 0.9953
# Epoch 119/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0299 - accuracy: 0.9928 - val_loss: 0.0285 - val_accuracy: 0.9935
# Epoch 120/150
# 5132/5132 [==============================] - 17s 3ms/step - loss: 0.0297 - accuracy: 0.9928 - val_loss: 0.0251 - val_accuracy: 0.9943
# Epoch 121/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0297 - accuracy: 0.9928 - val_loss: 0.0248 - val_accuracy: 0.9938
# Epoch 122/150
# 5132/5132 [==============================] - 15s 3ms/step - loss: 0.0297 - accuracy: 0.9929 - val_loss: 0.0249 - val_accuracy: 0.9943
# Epoch 123/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0299 - accuracy: 0.9929 - val_loss: 0.0247 - val_accuracy: 0.9938
# Epoch 124/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0297 - accuracy: 0.9928 - val_loss: 0.0245 - val_accuracy: 0.9938
# Epoch 125/150
# 5132/5132 [==============================] - 13s 3ms/step - loss: 0.0295 - accuracy: 0.9930 - val_loss: 0.0243 - val_accuracy: 0.9943
# Epoch 126/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0299 - accuracy: 0.9927 - val_loss: 0.0245 - val_accuracy: 0.9943
# Epoch 127/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0294 - accuracy: 0.9929 - val_loss: 0.0257 - val_accuracy: 0.9959
# Epoch 128/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0292 - accuracy: 0.9930 - val_loss: 0.0271 - val_accuracy: 0.9937
# Epoch 129/150
# 5132/5132 [==============================] - 16s 3ms/step - loss: 0.0297 - accuracy: 0.9928 - val_loss: 0.0247 - val_accuracy: 0.9938
# Epoch 130/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0296 - accuracy: 0.9930 - val_loss: 0.0284 - val_accuracy: 0.9934
# Epoch 131/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0291 - accuracy: 0.9931 - val_loss: 0.0249 - val_accuracy: 0.9944
# Epoch 132/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0292 - accuracy: 0.9929 - val_loss: 0.0245 - val_accuracy: 0.9959
# Epoch 133/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0290 - accuracy: 0.9929 - val_loss: 0.0241 - val_accuracy: 0.9943
# Epoch 134/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0292 - accuracy: 0.9929 - val_loss: 0.0280 - val_accuracy: 0.9958
# Epoch 135/150
# 5132/5132 [==============================] - 15s 3ms/step - loss: 0.0290 - accuracy: 0.9930 - val_loss: 0.0301 - val_accuracy: 0.9949
# Epoch 136/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0291 - accuracy: 0.9929 - val_loss: 0.0249 - val_accuracy: 0.9938
# Epoch 137/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0296 - accuracy: 0.9928 - val_loss: 0.0253 - val_accuracy: 0.9938
# Epoch 138/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0292 - accuracy: 0.9930 - val_loss: 0.0262 - val_accuracy: 0.9937
# Epoch 139/150
# 5132/5132 [==============================] - 15s 3ms/step - loss: 0.0288 - accuracy: 0.9932 - val_loss: 0.0244 - val_accuracy: 0.9943
# Epoch 140/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0292 - accuracy: 0.9932 - val_loss: 0.0238 - val_accuracy: 0.9943
# Epoch 141/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0289 - accuracy: 0.9929 - val_loss: 0.0246 - val_accuracy: 0.9945
# Epoch 142/150
# 5132/5132 [==============================] - 16s 3ms/step - loss: 0.0288 - accuracy: 0.9931 - val_loss: 0.0270 - val_accuracy: 0.9935
# Epoch 143/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0289 - accuracy: 0.9930 - val_loss: 0.0284 - val_accuracy: 0.9936
# Epoch 144/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0287 - accuracy: 0.9931 - val_loss: 0.0259 - val_accuracy: 0.9938
# Epoch 145/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0293 - accuracy: 0.9929 - val_loss: 0.0290 - val_accuracy: 0.9958
# Epoch 146/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0283 - accuracy: 0.9933 - val_loss: 0.0238 - val_accuracy: 0.9943
# Epoch 147/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0284 - accuracy: 0.9930 - val_loss: 0.0236 - val_accuracy: 0.9959
# Epoch 148/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0285 - accuracy: 0.9932 - val_loss: 0.0238 - val_accuracy: 0.9943
# Epoch 149/150
# 5132/5132 [==============================] - 14s 3ms/step - loss: 0.0284 - accuracy: 0.9930 - val_loss: 0.0262 - val_accuracy: 0.9938
# Epoch 150/150
# 5132/5132 [==============================] - 16s 3ms/step - loss: 0.0284 - accuracy: 0.9934 - val_loss: 0.0255 - val_accuracy: 0.9938

# %%
X_test = X_test.to_numpy()
x_test = np.reshape(X_test, (X_test.shape[0],1,X_test.shape[1]))

# %%
from keras.models import model_from_json # saving and loading trained model

filepath = 'lst_binary.json'
weightspath = 'lst_binary.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  lst_json = lst.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(lst_json)

  # serialize weights to HDF5
  lst.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  lst = model_from_json(loaded_model_json)

  # load weights into new model
  lst.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# load json and create model
json_file = open(filepath, 'r')
loaded_model_json = json_file.read()
json_file.close()
lst = model_from_json(loaded_model_json)

# load weights into new model
lst.load_weights(weightspath)
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = lst.evaluate(x_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 1070/1070 [==============================] - 2s 1ms/step - loss: 0.0257 - accuracy: 0.9936
# Test results - Loss: 0.025669820606708527 - Accuracy: 99.35694932937622%

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('lstm_binary_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('lstm_binary_loss.png')
plt.show()

# %%
from keras.utils import plot_model
# representation of model layers
plot_model(lst, to_file='lstm_binary.png', show_shapes=True,)

# %%
y_test.shape
# Out:
# (34212, 1)

# %%
y_pred = lst.predict(x_test)
# Out:
# 1070/1070 [==============================] - 2s 1ms/step

# %%
y_pred.shape
# Out:
# (34212, 1)

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

y_pred = lst.predict(x_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = auc(fpr, tpr)
# Out:
# 1070/1070 [==============================] - 1s 1ms/step

# %%
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig('lstm_binary_roc.png')
plt.show()

# %%
y_classes = (lst.predict(x_test)>0.5).astype('int32')
# Out:
# 1070/1070 [==============================] - 1s 1ms/step

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))
# Out:
# Recall Score -  1.0
# F1 Score -  0.9936324167872649
# Precision Score -  0.9873454127121082
